# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Setting up the possible latent dimensions
# A total of 26 latent dimensions are taken under consideration

k_list = []
k_list.extend(list(range(2, 10)))
k_list.extend(list(range(10, 20, 2)))
k_list.extend(list(range(20, 50, 5)))
k_list.extend(list(range(50, 61, 10)))
k_list.append(78)
k_list.extend(list(range(80, 100, 10)))
k_list.extend(list(range(100, 151, 25)))

print("Latent dimensions:")
print(k_list)
# Out:
# Latent dimensions:
# [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 14, 16, 18, 20, 25, 30, 35, 40, 45, 50, 60, 78, 80, 90, 100, 125, 150]

# %%
dae = []
for k in k_list:
    df = pd.read_csv("data/dae/dae_latent_"+str(k)+".csv", index_col=0)
    dae.append(df.iloc[-1][0])

# %%
plt.figure()
plt.plot(k_list, dae, '.-')
plt.title("Reconstruction cost for DAE model")
plt.xlabel("Latent dimesion")
plt.ylabel("Reconstruction cost")
plt.grid()
plt.show()

# %%
vae = []
for k in k_list:
    df = pd.read_csv("data/vae/vae_latent_"+str(k)+".csv", index_col=0)
    vae.append(df.iloc[-1][0])

# %%
plt.figure()
plt.plot(k_list, vae, '.-')
plt.title("Reconstruction cost for VAE model")
plt.xlabel("Latent dimesion")
plt.ylabel("Reconstruction cost")
plt.grid()
plt.show()
