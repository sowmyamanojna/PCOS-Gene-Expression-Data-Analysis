# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmyamanojna/CS6024-Algorithmic-Approaches-to-Computational-Biology-Project/blob/master/pcos_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("control_pcos_celltype_mapping.csv")
display(df)
# Out:
#       sample_id PCOS/Control    cell_type  dataset
# 0    GSM1174425         PCOS  endothelial  GDS4987
# 1    GSM1174429         PCOS  endothelial  GDS4987
# 2    GSM1174436         PCOS  endothelial  GDS4987
# 3    GSM1174427         PCOS   epithelial  GDS4987
# 4    GSM1174430         PCOS   epithelial  GDS4987
# ..          ...          ...          ...      ...
# 170    GSM27534      control        theca  GDS1050
# 171    GSM27543     valproic        theca  GDS1050
# 172    GSM27546     valproic        theca  GDS1050
# 173    GSM27548     valproic        theca  GDS1050
# 174    GSM27549     valproic        theca  GDS1050
#
# [175 rows x 4 columns]

# %%
cell_types = list(set(df['cell_type']))
print(cell_types)
cell_type_freqs = [len(df[df['cell_type'] == x]) for x in cell_types]
cell_type_freqs = [(x/len(df))*100 for x in cell_type_freqs]
print(cell_type_freqs)
# Out:
# ['stromal', 'epithelial', 'adipose', 'granulosa', 'theca', 'mesenchymal', 'cumulus', 'vastus_lateralis_muscle', 'endothelial']
# [4.571428571428571, 4.0, 8.571428571428571, 5.714285714285714, 14.857142857142858, 4.0, 13.142857142857142, 41.14285714285714, 4.0]

# %%
fig1, ax1 = plt.subplots()
ax1.pie(cell_type_freqs, labels=cell_types, autopct='%1.1f%%', shadow=True)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Cell types in PCOS dataset')
# plt.show()
plt.savefig('cell_types.png')

# %%
pcos_control_drug = list(set(df['PCOS/Control']))
print(pcos_control_drug)
pcos_control_drug_freqs = [len(df[df['PCOS/Control'] == x]) for x in pcos_control_drug]
pcos_control_drug_freqs = [(x/len(df))*100 for x in pcos_control_drug_freqs]
print(pcos_control_drug_freqs)
# Out:
# ['pioglitazone', 'PCOS_lean', 'PCOS', 'obese', 'PCOS_obese', 'PCOS_insulin_res', 'valproic', 'control', 'lean']
# [5.714285714285714, 2.857142857142857, 28.000000000000004, 10.285714285714285, 4.0, 9.142857142857142, 4.571428571428571, 32.0, 3.428571428571429]

# %%
fig2, ax2 = plt.subplots()
ax2.pie(pcos_control_drug_freqs, labels=pcos_control_drug, autopct='%1.1f%%', shadow=True)

ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Types of samples in PCOS dataset')
# plt.show()
plt.savefig('pcos_control_drug.png')

# %%
datasets = list(set(df['dataset']))
print(datasets)
# Out:
# ['GDS3841', 'GDS1051', 'GDS3104', 'GDS1050', 'GDS4987', 'GDS4133', 'GDS4132', 'GDS4399', 'GDS2084']
